# %%
# !pip install pandas numpy scikit-learn transformers datasets pyspark wandb
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Collecting datasets
#   Downloading datasets-3.0.2-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.3)
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (0.18.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (16.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.10)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from wandb) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.17.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (75.1.0)
# Requirement already satisfied: typing-extensions<5,>=4.4 in /usr/local/lib/python3.10/dist-packages (from wandb) (4.12.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.16.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)
# Downloading datasets-3.0.2-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.7/472.7 kB 8.5 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.9 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.7 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-3.0.2 dill-0.3.8 multiprocess-0.70.16 xxhash-3.5.0

# %%
import pandas as pd
import numpy as np
import logging
from datetime import datetime
from google.colab import drive
from pyspark.sql import SparkSession
from transformers import pipeline, AutoTokenizer, AutoModelForMaskedLM, Trainer, TrainingArguments
from sklearn.metrics import mean_squared_error
from datasets import Dataset
import warnings

# Suppress non-essential warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# Mount Google Drive for persistent storage
drive.mount('/content/drive', force_remount=True)

# Set up logging
logging.basicConfig(filename='/content/drive/MyDrive/training_log.log', level=logging.INFO)

def log_message(message):
    logging.info(f"{datetime.now()}: {message}")
    print(message)  # Also print to console for real-time monitoring

# Initialize PySpark session
spark = SparkSession.builder.appName("AirQualityProcessing").getOrCreate()

log_message("Loading dataset...")

# Load the dataset with pandas
full_dataset_path = '/content/drive/MyDrive/AirQualityUCI.csv'  # Replace with your actual path
full_dataset = pd.read_csv(full_dataset_path, sep=';', decimal=',')

# Convert pandas DataFrame to Spark DataFrame for processing
spark_df = spark.createDataFrame(full_dataset)

# Drop rows with empty columns to clean data
spark_df = spark_df.dropna(how="all", subset=["RH", "Date", "Time", "CO(GT)"])

# Convert back to Pandas DataFrame for Hugging Face compatibility
full_dataset = spark_df.toPandas()
log_message("Dataset loaded and cleaned.")

# Extract 'RH' column for ground truth values
full_rh_values = full_dataset['RH'].copy()
dataset = full_dataset.copy()
dataset['RH'] = dataset['RH'].astype(str)

# Randomly mask 20% of 'RH' values
log_message("Masking 20% of RH values...")
missing_indices = np.random.choice(dataset.index, size=int(0.2 * len(dataset)), replace=False)
dataset.loc[missing_indices, 'RH'] = '[MASK]'

# Prepare formatted text for model input with adjusted prompt
dataset_text = dataset.apply(lambda row: f"The RH value for Date {row['Date']} at Time {row['Time']} with CO(GT) {row['CO(GT)']} is approximately [MASK].", axis=1)

# Load tokenizer and model
log_message("Loading model and tokenizer...")
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased", clean_up_tokenization_spaces=True)
model = AutoModelForMaskedLM.from_pretrained("bert-base-uncased")

# Define a function to tokenize input and set up labels for masked language modeling
def prepare_input_for_model(text):
    encoding = tokenizer(
        text,
        padding="max_length",
        max_length=128,
        truncation=True,
        return_tensors="pt"
    )
    encoding["labels"] = encoding["input_ids"].clone()
    return encoding

# Prepare dataset for training
log_message("Preparing dataset for training...")
encoded_data = [prepare_input_for_model(text) for text in dataset_text]
encoded_dataset = Dataset.from_dict({
    "input_ids": [d['input_ids'][0] for d in encoded_data],
    "attention_mask": [d['attention_mask'][0] for d in encoded_data],
    "labels": [d['labels'][0] for d in encoded_data]
})

# Define training arguments with checkpoint saving
training_args = TrainingArguments(
    output_dir="/content/drive/MyDrive/checkpoints",
    save_steps=500,
    save_total_limit=3,
    logging_dir="/content/drive/MyDrive/logs",
    logging_steps=100,
    per_device_train_batch_size=8,  # Set this lower if running out of GPU memory
    num_train_epochs=3,  # Increased epochs for better learning
    report_to="none"
)

# Initialize Trainer for model training
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=encoded_dataset
)

# Log the start of training
log_message("Training started.")

# Try resuming from last checkpoint if interrupted
try:
    trainer.train(resume_from_checkpoint=False)  # Set to False to avoid checkpoint issues
except Exception as e:
    log_message(f"Training interrupted. Error: {e}")

log_message("Training complete.")

# Set up pipeline to fill in missing RH values with GPU if available
fill_pipeline = pipeline("fill-mask", model=model, tokenizer=tokenizer, device=0)
log_message("Pipeline ready for inference.")

# Set batch size for inference based on available GPU RAM
batch_size = 16  # Adjust batch size to prevent GPU overload

# Calculate fallback prediction (mean RH) for use when `[MASK]` is predicted
fallback_rh_value = full_rh_values.mean()

# Create batched input texts for missing RH values with adjusted prompt
batched_inputs = [
    f"The RH value for Date {row['Date']} at Time {row['Time']} with CO(GT) {row['CO(GT)']} is approximately [MASK]."
    for idx, row in dataset.iloc[missing_indices].iterrows()
]

# Initialize lists to store predictions and actual values for MSE calculation
predicted_rh_values = []
true_rh_values = []

# Process inputs in batches to maximize GPU efficiency
log_message("Starting batch inference with adjusted prompt...")
for i in range(0, len(batched_inputs), batch_size):
    batch = batched_inputs[i:i + batch_size]
    predictions = fill_pipeline(batch)

    for j, prediction in enumerate(predictions):
        try:
            # Extract and log the predicted token
            predicted_token = prediction[0]['token_str'].replace(",", "").strip()
            log_message(f"Predicted token for batch {i // batch_size + 1}, item {j + 1}: {predicted_token}")

            # Convert the predicted token to a float, use fallback if it's still `[MASK]`
            if predicted_token == '[MASK]':
                predicted_value = fallback_rh_value
                log_message(f"Fallback used for batch {i // batch_size + 1}, item {j + 1}")
            else:
                predicted_value = float(predicted_token)

            predicted_rh_values.append(predicted_value)
            true_rh_values.append(float(full_rh_values.iloc[missing_indices[i + j]]))
        except (ValueError, IndexError) as e:
            # Log if there's an issue converting the prediction
            log_message(f"Error in prediction conversion for batch {i // batch_size + 1}, item {j + 1}: {e}")
            predicted_rh_values.append(fallback_rh_value)
            continue

    log_message(f"Batch {i // batch_size + 1} of {len(batched_inputs) // batch_size + 1} processed.")

# Filter out NaN values in true_rh_values and predicted_rh_values before calculating MSE
true_rh_values_filtered = [val for val in true_rh_values if not np.isnan(val)]
predicted_rh_values_filtered = [predicted_rh_values[i] for i in range(len(predicted_rh_values)) if not np.isnan(true_rh_values[i])]

# Check if we have valid predictions to calculate MSE
if true_rh_values_filtered and predicted_rh_values_filtered:
    mse = mean_squared_error(true_rh_values_filtered, predicted_rh_values_filtered)
    log_message(f"Mean Squared Error (MSE) of the predictions: {mse}")
else:
    log_message("No valid predictions were available to calculate MSE.")

# Stop the Spark session
spark.stop()
log_message("Process complete.")
# Out:
# Mounted at /content/drive
# Loading dataset...
# Dataset loaded and cleaned.
# Masking 20% of RH values...
# Loading model and tokenizer...
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Preparing dataset for training...
# Training started.
#     <div>
#
#       <progress value='3552' max='3552' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3552/3552 15:31, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.846600</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.000400</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.000200</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.001300</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.001000</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.000500</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# Training complete.
# Pipeline ready for inference.
# Starting batch inference with adjusted prompt...
# Predicted token for batch 1, item 1: [MASK]
# Fallback used for batch 1, item 1
# Predicted token for batch 1, item 2: [MASK]
# Fallback used for batch 1, item 2
# Predicted token for batch 1, item 3: [MASK]
# Fallback used for batch 1, item 3
# Predicted token for batch 1, item 4: [MASK]
# Fallback used for batch 1, item 4
# Predicted token for batch 1, item 5: [MASK]
# Fallback used for batch 1, item 5
# Predicted token for batch 1, item 6: [MASK]
# Fallback used for batch 1, item 6
# Predicted token for batch 1, item 7: [MASK]
# Fallback used for batch 1, item 7
# Predicted token for batch 1, item 8: [MASK]
# Fallback used for batch 1, item 8
# Predicted token for batch 1, item 9: [MASK]
# Fallback used for batch 1, item 9
# Predicted token for batch 1, item 10: [MASK]
# Fallback used for batch 1, item 10
# Predicted token for batch 1, item 11: [MASK]
# Fallback used for batch 1, item 11
# Predicted token for batch 1, item 12: [MASK]
# Fallback used for batch 1, item 12
# Predicted token for batch 1, item 13: [MASK]
# Fallback used for batch 1, item 13
# Predicted token for batch 1, item 14: [MASK]
# Fallback used for batch 1, item 14
# Predicted token for batch 1, item 15: [MASK]
# Fallback used for batch 1, item 15
# Predicted token for batch 1, item 16: [MASK]
# Fallback used for batch 1, item 16
# Batch 1 of 119 processed.
# Predicted token for batch 2, item 1: [MASK]
# Fallback used for batch 2, item 1
# Predicted token for batch 2, item 2: [MASK]
# Fallback used for batch 2, item 2
# Predicted token for batch 2, item 3: [MASK]
# Fallback used for batch 2, item 3
# Predicted token for batch 2, item 4: [MASK]
# Fallback used for batch 2, item 4
# Predicted token for batch 2, item 5: [MASK]
# Fallback used for batch 2, item 5
# Predicted token for batch 2, item 6: [MASK]
# Fallback used for batch 2, item 6
# Predicted token for batch 2, item 7: [MASK]
# Fallback used for batch 2, item 7
# Predicted token for batch 2, item 8: [MASK]
# Fallback used for batch 2, item 8
# Predicted token for batch 2, item 9: [MASK]
# Fallback used for batch 2, item 9
# Predicted token for batch 2, item 10: [MASK]
# Fallback used for batch 2, item 10
# Predicted token for batch 2, item 11: [MASK]
# Fallback used for batch 2, item 11
# Predicted token for batch 2, item 12: [MASK]
# Fallback used for batch 2, item 12
# Predicted token for batch 2, item 13: [MASK]
# Fallback used for batch 2, item 13
# Predicted token for batch 2, item 14: [MASK]
# Fallback used for batch 2, item 14
# Predicted token for batch 2, item 15: [MASK]
# Fallback used for batch 2, item 15
# Predicted token for batch 2, item 16: [MASK]
# Fallback used for batch 2, item 16
# Batch 2 of 119 processed.
# Predicted token for batch 3, item 1: [MASK]
# Fallback used for batch 3, item 1
# Predicted token for batch 3, item 2: [MASK]
# Fallback used for batch 3, item 2
# Predicted token for batch 3, item 3: [MASK]
# Fallback used for batch 3, item 3
# Predicted token for batch 3, item 4: [MASK]
# Fallback used for batch 3, item 4
# Predicted token for batch 3, item 5: [MASK]
# Fallback used for batch 3, item 5
# Predicted token for batch 3, item 6: [MASK]
# Fallback used for batch 3, item 6
# Predicted token for batch 3, item 7: [MASK]
# Fallback used for batch 3, item 7
# Predicted token for batch 3, item 8: [MASK]
# Fallback used for batch 3, item 8
# Predicted token for batch 3, item 9: [MASK]
# Fallback used for batch 3, item 9
# Predicted token for batch 3, item 10: [MASK]
# Fallback used for batch 3, item 10
# Predicted token for batch 3, item 11: [MASK]
# Fallback used for batch 3, item 11
# Predicted token for batch 3, item 12: [MASK]
# Fallback used for batch 3, item 12
# Predicted token for batch 3, item 13: [MASK]
# Fallback used for batch 3, item 13
# Predicted token for batch 3, item 14: [MASK]
# Fallback used for batch 3, item 14
# Predicted token for batch 3, item 15: [MASK]
# Fallback used for batch 3, item 15
# Predicted token for batch 3, item 16: [MASK]
# Fallback used for batch 3, item 16
# Batch 3 of 119 processed.
# Predicted token for batch 4, item 1: [MASK]
# Fallback used for batch 4, item 1
# Predicted token for batch 4, item 2: [MASK]
# Fallback used for batch 4, item 2
# Predicted token for batch 4, item 3: [MASK]
# Fallback used for batch 4, item 3
# Predicted token for batch 4, item 4: [MASK]
# Fallback used for batch 4, item 4
# Predicted token for batch 4, item 5: [MASK]
# Fallback used for batch 4, item 5
# Predicted token for batch 4, item 6: [MASK]
# Fallback used for batch 4, item 6
# Predicted token for batch 4, item 7: [MASK]
# Fallback used for batch 4, item 7
# Predicted token for batch 4, item 8: [MASK]
# Fallback used for batch 4, item 8
# Predicted token for batch 4, item 9: [MASK]
# Fallback used for batch 4, item 9
# Predicted token for batch 4, item 10: [MASK]
# Fallback used for batch 4, item 10
# Predicted token for batch 4, item 11: [MASK]
# Fallback used for batch 4, item 11
# Predicted token for batch 4, item 12: [MASK]
# Fallback used for batch 4, item 12
# Predicted token for batch 4, item 13: [MASK]
# Fallback used for batch 4, item 13
# Predicted token for batch 4, item 14: [MASK]
# Fallback used for batch 4, item 14
# Predicted token for batch 4, item 15: [MASK]
# Fallback used for batch 4, item 15
# Predicted token for batch 4, item 16: [MASK]
# Fallback used for batch 4, item 16
# Batch 4 of 119 processed.
# Predicted token for batch 5, item 1: [MASK]
# Fallback used for batch 5, item 1
# Predicted token for batch 5, item 2: [MASK]
# Fallback used for batch 5, item 2
# Predicted token for batch 5, item 3: [MASK]
# Fallback used for batch 5, item 3
# Predicted token for batch 5, item 4: [MASK]
# Fallback used for batch 5, item 4
# Predicted token for batch 5, item 5: [MASK]
# Fallback used for batch 5, item 5
# Predicted token for batch 5, item 6: [MASK]
# Fallback used for batch 5, item 6
# Predicted token for batch 5, item 7: [MASK]
# Fallback used for batch 5, item 7
# Predicted token for batch 5, item 8: [MASK]
# Fallback used for batch 5, item 8
# Predicted token for batch 5, item 9: [MASK]
# Fallback used for batch 5, item 9
# Predicted token for batch 5, item 10: [MASK]
# Fallback used for batch 5, item 10
# Predicted token for batch 5, item 11: [MASK]
# Fallback used for batch 5, item 11
# Predicted token for batch 5, item 12: [MASK]
# Fallback used for batch 5, item 12
# Predicted token for batch 5, item 13: [MASK]
# Fallback used for batch 5, item 13
# Predicted token for batch 5, item 14: [MASK]
# Fallback used for batch 5, item 14
# Predicted token for batch 5, item 15: [MASK]
# Fallback used for batch 5, item 15
# Predicted token for batch 5, item 16: [MASK]
# Fallback used for batch 5, item 16
# Batch 5 of 119 processed.
# Predicted token for batch 6, item 1: [MASK]
# Fallback used for batch 6, item 1
# Predicted token for batch 6, item 2: [MASK]
# Fallback used for batch 6, item 2
# Predicted token for batch 6, item 3: [MASK]
# Fallback used for batch 6, item 3
# Predicted token for batch 6, item 4: [MASK]
# Fallback used for batch 6, item 4
# Predicted token for batch 6, item 5: [MASK]
# Fallback used for batch 6, item 5
# Predicted token for batch 6, item 6: [MASK]
# Fallback used for batch 6, item 6
# Predicted token for batch 6, item 7: [MASK]
# Fallback used for batch 6, item 7
# Predicted token for batch 6, item 8: [MASK]
# Fallback used for batch 6, item 8
# Predicted token for batch 6, item 9: [MASK]
# Fallback used for batch 6, item 9
# Predicted token for batch 6, item 10: [MASK]
# Fallback used for batch 6, item 10
# Predicted token for batch 6, item 11: [MASK]
# Fallback used for batch 6, item 11
# Predicted token for batch 6, item 12: [MASK]
# Fallback used for batch 6, item 12
# Predicted token for batch 6, item 13: [MASK]
# Fallback used for batch 6, item 13
# Predicted token for batch 6, item 14: [MASK]
# Fallback used for batch 6, item 14
# Predicted token for batch 6, item 15: [MASK]
# Fallback used for batch 6, item 15
# Predicted token for batch 6, item 16: [MASK]
# Fallback used for batch 6, item 16
# Batch 6 of 119 processed.
# Predicted token for batch 7, item 1: [MASK]
# Fallback used for batch 7, item 1
# Predicted token for batch 7, item 2: [MASK]
# Fallback used for batch 7, item 2
# Predicted token for batch 7, item 3: [MASK]
# Fallback used for batch 7, item 3
# Predicted token for batch 7, item 4: [MASK]
# Fallback used for batch 7, item 4
# Predicted token for batch 7, item 5: [MASK]
# Fallback used for batch 7, item 5
# Predicted token for batch 7, item 6: [MASK]
# Fallback used for batch 7, item 6
# Predicted token for batch 7, item 7: [MASK]
# Fallback used for batch 7, item 7
# Predicted token for batch 7, item 8: [MASK]
# Fallback used for batch 7, item 8
# Predicted token for batch 7, item 9: [MASK]
# Fallback used for batch 7, item 9
# Predicted token for batch 7, item 10: [MASK]
# Fallback used for batch 7, item 10
# Predicted token for batch 7, item 11: [MASK]
# Fallback used for batch 7, item 11
# Predicted token for batch 7, item 12: [MASK]
# Fallback used for batch 7, item 12
# Predicted token for batch 7, item 13: [MASK]
# Fallback used for batch 7, item 13
# Predicted token for batch 7, item 14: [MASK]
# Fallback used for batch 7, item 14
# Predicted token for batch 7, item 15: [MASK]
# Fallback used for batch 7, item 15
# Predicted token for batch 7, item 16: [MASK]
# Fallback used for batch 7, item 16
# Batch 7 of 119 processed.
# Predicted token for batch 8, item 1: [MASK]
# Fallback used for batch 8, item 1
# Predicted token for batch 8, item 2: [MASK]
# Fallback used for batch 8, item 2
# Predicted token for batch 8, item 3: [MASK]
# Fallback used for batch 8, item 3
# Predicted token for batch 8, item 4: [MASK]
# Fallback used for batch 8, item 4
# Predicted token for batch 8, item 5: [MASK]
# Fallback used for batch 8, item 5
# Predicted token for batch 8, item 6: [MASK]
# Fallback used for batch 8, item 6
# Predicted token for batch 8, item 7: [MASK]
# Fallback used for batch 8, item 7
# Predicted token for batch 8, item 8: [MASK]
# Fallback used for batch 8, item 8
# Predicted token for batch 8, item 9: [MASK]
# Fallback used for batch 8, item 9
# Predicted token for batch 8, item 10: [MASK]
# Fallback used for batch 8, item 10
# Predicted token for batch 8, item 11: [MASK]
# Fallback used for batch 8, item 11
# Predicted token for batch 8, item 12: [MASK]
# Fallback used for batch 8, item 12
# Predicted token for batch 8, item 13: [MASK]
# Fallback used for batch 8, item 13
# Predicted token for batch 8, item 14: [MASK]
# Fallback used for batch 8, item 14
# Predicted token for batch 8, item 15: [MASK]
# Fallback used for batch 8, item 15
# Predicted token for batch 8, item 16: [MASK]
# Fallback used for batch 8, item 16
# Batch 8 of 119 processed.
# Predicted token for batch 9, item 1: [MASK]
# Fallback used for batch 9, item 1
# Predicted token for batch 9, item 2: [MASK]
# Fallback used for batch 9, item 2
# Predicted token for batch 9, item 3: [MASK]
# Fallback used for batch 9, item 3
# Predicted token for batch 9, item 4: [MASK]
# Fallback used for batch 9, item 4
# Predicted token for batch 9, item 5: [MASK]
# Fallback used for batch 9, item 5
# Predicted token for batch 9, item 6: [MASK]
# Fallback used for batch 9, item 6
# Predicted token for batch 9, item 7: [MASK]
# Fallback used for batch 9, item 7
# Predicted token for batch 9, item 8: [MASK]
# Fallback used for batch 9, item 8
# Predicted token for batch 9, item 9: [MASK]
# Fallback used for batch 9, item 9
# Predicted token for batch 9, item 10: [MASK]
# Fallback used for batch 9, item 10
# Predicted token for batch 9, item 11: [MASK]
# Fallback used for batch 9, item 11
# Predicted token for batch 9, item 12: [MASK]
# Fallback used for batch 9, item 12
# Predicted token for batch 9, item 13: [MASK]
# Fallback used for batch 9, item 13
# Predicted token for batch 9, item 14: [MASK]
# Fallback used for batch 9, item 14
# Predicted token for batch 9, item 15: [MASK]
# Fallback used for batch 9, item 15
# Predicted token for batch 9, item 16: [MASK]
# Fallback used for batch 9, item 16
# Batch 9 of 119 processed.
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Predicted token for batch 10, item 1: [MASK]
# Fallback used for batch 10, item 1
# Predicted token for batch 10, item 2: [MASK]
# Fallback used for batch 10, item 2
# Predicted token for batch 10, item 3: [MASK]
# Fallback used for batch 10, item 3
# Predicted token for batch 10, item 4: [MASK]
# Fallback used for batch 10, item 4
# Predicted token for batch 10, item 5: [MASK]
# Fallback used for batch 10, item 5
# Predicted token for batch 10, item 6: [MASK]
# Fallback used for batch 10, item 6
# Predicted token for batch 10, item 7: [MASK]
# Fallback used for batch 10, item 7
# Predicted token for batch 10, item 8: [MASK]
# Fallback used for batch 10, item 8
# Predicted token for batch 10, item 9: [MASK]
# Fallback used for batch 10, item 9
# Predicted token for batch 10, item 10: [MASK]
# Fallback used for batch 10, item 10
# Predicted token for batch 10, item 11: [MASK]
# Fallback used for batch 10, item 11
# Predicted token for batch 10, item 12: [MASK]
# Fallback used for batch 10, item 12
# Predicted token for batch 10, item 13: [MASK]
# Fallback used for batch 10, item 13
# Predicted token for batch 10, item 14: [MASK]
# Fallback used for batch 10, item 14
# Predicted token for batch 10, item 15: [MASK]
# Fallback used for batch 10, item 15
# Predicted token for batch 10, item 16: [MASK]
# Fallback used for batch 10, item 16
# Batch 10 of 119 processed.
# Predicted token for batch 11, item 1: [MASK]
# Fallback used for batch 11, item 1
# Predicted token for batch 11, item 2: [MASK]
# Fallback used for batch 11, item 2
# Predicted token for batch 11, item 3: [MASK]
# Fallback used for batch 11, item 3
# Predicted token for batch 11, item 4: [MASK]
# Fallback used for batch 11, item 4
# Predicted token for batch 11, item 5: [MASK]
# Fallback used for batch 11, item 5
# Predicted token for batch 11, item 6: [MASK]
# Fallback used for batch 11, item 6
# Predicted token for batch 11, item 7: [MASK]
# Fallback used for batch 11, item 7
# Predicted token for batch 11, item 8: [MASK]
# Fallback used for batch 11, item 8
# Predicted token for batch 11, item 9: [MASK]
# Fallback used for batch 11, item 9
# Predicted token for batch 11, item 10: [MASK]
# Fallback used for batch 11, item 10
# Predicted token for batch 11, item 11: [MASK]
# Fallback used for batch 11, item 11
# Predicted token for batch 11, item 12: [MASK]
# Fallback used for batch 11, item 12
# Predicted token for batch 11, item 13: [MASK]
# Fallback used for batch 11, item 13
# Predicted token for batch 11, item 14: [MASK]
# Fallback used for batch 11, item 14
# Predicted token for batch 11, item 15: [MASK]
# Fallback used for batch 11, item 15
# Predicted token for batch 11, item 16: [MASK]
# Fallback used for batch 11, item 16
# Batch 11 of 119 processed.
# Predicted token for batch 12, item 1: [MASK]
# Fallback used for batch 12, item 1
# Predicted token for batch 12, item 2: [MASK]
# Fallback used for batch 12, item 2
# Predicted token for batch 12, item 3: [MASK]
# Fallback used for batch 12, item 3
# Predicted token for batch 12, item 4: [MASK]
# Fallback used for batch 12, item 4
# Predicted token for batch 12, item 5: [MASK]
# Fallback used for batch 12, item 5
# Predicted token for batch 12, item 6: [MASK]
# Fallback used for batch 12, item 6
# Predicted token for batch 12, item 7: [MASK]
# Fallback used for batch 12, item 7
# Predicted token for batch 12, item 8: [MASK]
# Fallback used for batch 12, item 8
# Predicted token for batch 12, item 9: [MASK]
# Fallback used for batch 12, item 9
# Predicted token for batch 12, item 10: [MASK]
# Fallback used for batch 12, item 10
# Predicted token for batch 12, item 11: [MASK]
# Fallback used for batch 12, item 11
# Predicted token for batch 12, item 12: [MASK]
# Fallback used for batch 12, item 12
# Predicted token for batch 12, item 13: [MASK]
# Fallback used for batch 12, item 13
# Predicted token for batch 12, item 14: [MASK]
# Fallback used for batch 12, item 14
# Predicted token for batch 12, item 15: [MASK]
# Fallback used for batch 12, item 15
# Predicted token for batch 12, item 16: [MASK]
# Fallback used for batch 12, item 16
# Batch 12 of 119 processed.
# Predicted token for batch 13, item 1: [MASK]
# Fallback used for batch 13, item 1
# Predicted token for batch 13, item 2: [MASK]
# Fallback used for batch 13, item 2
# Predicted token for batch 13, item 3: [MASK]
# Fallback used for batch 13, item 3
# Predicted token for batch 13, item 4: [MASK]
# Fallback used for batch 13, item 4
# Predicted token for batch 13, item 5: [MASK]
# Fallback used for batch 13, item 5
# Predicted token for batch 13, item 6: [MASK]
# Fallback used for batch 13, item 6
# Predicted token for batch 13, item 7: [MASK]
# Fallback used for batch 13, item 7
# Predicted token for batch 13, item 8: [MASK]
# Fallback used for batch 13, item 8
# Predicted token for batch 13, item 9: [MASK]
# Fallback used for batch 13, item 9
# Predicted token for batch 13, item 10: [MASK]
# Fallback used for batch 13, item 10
# Predicted token for batch 13, item 11: [MASK]
# Fallback used for batch 13, item 11
# Predicted token for batch 13, item 12: [MASK]
# Fallback used for batch 13, item 12
# Predicted token for batch 13, item 13: [MASK]
# Fallback used for batch 13, item 13
# Predicted token for batch 13, item 14: [MASK]
# Fallback used for batch 13, item 14
# Predicted token for batch 13, item 15: [MASK]
# Fallback used for batch 13, item 15
# Predicted token for batch 13, item 16: [MASK]
# Fallback used for batch 13, item 16
# Batch 13 of 119 processed.
# Predicted token for batch 14, item 1: [MASK]
# Fallback used for batch 14, item 1
# Predicted token for batch 14, item 2: [MASK]
# Fallback used for batch 14, item 2
# Predicted token for batch 14, item 3: [MASK]
# Fallback used for batch 14, item 3
# Predicted token for batch 14, item 4: [MASK]
# Fallback used for batch 14, item 4
# Predicted token for batch 14, item 5: [MASK]
# Fallback used for batch 14, item 5
# Predicted token for batch 14, item 6: [MASK]
# Fallback used for batch 14, item 6
# Predicted token for batch 14, item 7: [MASK]
# Fallback used for batch 14, item 7
# Predicted token for batch 14, item 8: [MASK]
# Fallback used for batch 14, item 8
# Predicted token for batch 14, item 9: [MASK]
# Fallback used for batch 14, item 9
# Predicted token for batch 14, item 10: [MASK]
# Fallback used for batch 14, item 10
# Predicted token for batch 14, item 11: [MASK]
# Fallback used for batch 14, item 11
# Predicted token for batch 14, item 12: [MASK]
# Fallback used for batch 14, item 12
# Predicted token for batch 14, item 13: [MASK]
# Fallback used for batch 14, item 13
# Predicted token for batch 14, item 14: [MASK]
# Fallback used for batch 14, item 14
# Predicted token for batch 14, item 15: [MASK]
# Fallback used for batch 14, item 15
# Predicted token for batch 14, item 16: [MASK]
# Fallback used for batch 14, item 16
# Batch 14 of 119 processed.
# Predicted token for batch 15, item 1: [MASK]
# Fallback used for batch 15, item 1
# Predicted token for batch 15, item 2: [MASK]
# Fallback used for batch 15, item 2
# Predicted token for batch 15, item 3: [MASK]
# Fallback used for batch 15, item 3
# Predicted token for batch 15, item 4: [MASK]
# Fallback used for batch 15, item 4
# Predicted token for batch 15, item 5: [MASK]
# Fallback used for batch 15, item 5
# Predicted token for batch 15, item 6: [MASK]
# Fallback used for batch 15, item 6
# Predicted token for batch 15, item 7: [MASK]
# Fallback used for batch 15, item 7
# Predicted token for batch 15, item 8: [MASK]
# Fallback used for batch 15, item 8
# Predicted token for batch 15, item 9: [MASK]
# Fallback used for batch 15, item 9
# Predicted token for batch 15, item 10: [MASK]
# Fallback used for batch 15, item 10
# Predicted token for batch 15, item 11: [MASK]
# Fallback used for batch 15, item 11
# Predicted token for batch 15, item 12: [MASK]
# Fallback used for batch 15, item 12
# Predicted token for batch 15, item 13: [MASK]
# Fallback used for batch 15, item 13
# Predicted token for batch 15, item 14: [MASK]
# Fallback used for batch 15, item 14
# Predicted token for batch 15, item 15: [MASK]
# Fallback used for batch 15, item 15
# Predicted token for batch 15, item 16: [MASK]
# Fallback used for batch 15, item 16
# Batch 15 of 119 processed.
# Predicted token for batch 16, item 1: [MASK]
# Fallback used for batch 16, item 1
# Predicted token for batch 16, item 2: [MASK]
# Fallback used for batch 16, item 2
# Predicted token for batch 16, item 3: [MASK]
# Fallback used for batch 16, item 3
# Predicted token for batch 16, item 4: [MASK]
# Fallback used for batch 16, item 4
# Predicted token for batch 16, item 5: [MASK]
# Fallback used for batch 16, item 5
# Predicted token for batch 16, item 6: [MASK]
# Fallback used for batch 16, item 6
# Predicted token for batch 16, item 7: [MASK]
# Fallback used for batch 16, item 7
# Predicted token for batch 16, item 8: [MASK]
# Fallback used for batch 16, item 8
# Predicted token for batch 16, item 9: [MASK]
# Fallback used for batch 16, item 9
# Predicted token for batch 16, item 10: [MASK]
# Fallback used for batch 16, item 10
# Predicted token for batch 16, item 11: [MASK]
# Fallback used for batch 16, item 11
# Predicted token for batch 16, item 12: [MASK]
# Fallback used for batch 16, item 12
# Predicted token for batch 16, item 13: [MASK]
# Fallback used for batch 16, item 13
# Predicted token for batch 16, item 14: [MASK]
# Fallback used for batch 16, item 14
# Predicted token for batch 16, item 15: [MASK]
# Fallback used for batch 16, item 15
# Predicted token for batch 16, item 16: [MASK]
# Fallback used for batch 16, item 16
# Batch 16 of 119 processed.
# Predicted token for batch 17, item 1: [MASK]
# Fallback used for batch 17, item 1
# Predicted token for batch 17, item 2: [MASK]
# Fallback used for batch 17, item 2
# Predicted token for batch 17, item 3: [MASK]
# Fallback used for batch 17, item 3
# Predicted token for batch 17, item 4: [MASK]
# Fallback used for batch 17, item 4
# Predicted token for batch 17, item 5: [MASK]
# Fallback used for batch 17, item 5
# Predicted token for batch 17, item 6: [MASK]
# Fallback used for batch 17, item 6
# Predicted token for batch 17, item 7: [MASK]
# Fallback used for batch 17, item 7
# Predicted token for batch 17, item 8: [MASK]
# Fallback used for batch 17, item 8
# Predicted token for batch 17, item 9: [MASK]
# Fallback used for batch 17, item 9
# Predicted token for batch 17, item 10: [MASK]
# Fallback used for batch 17, item 10
# Predicted token for batch 17, item 11: [MASK]
# Fallback used for batch 17, item 11
# Predicted token for batch 17, item 12: [MASK]
# Fallback used for batch 17, item 12
# Predicted token for batch 17, item 13: [MASK]
# Fallback used for batch 17, item 13
# Predicted token for batch 17, item 14: [MASK]
# Fallback used for batch 17, item 14
# Predicted token for batch 17, item 15: [MASK]
# Fallback used for batch 17, item 15
# Predicted token for batch 17, item 16: [MASK]
# Fallback used for batch 17, item 16
# Batch 17 of 119 processed.
# Predicted token for batch 18, item 1: [MASK]
# Fallback used for batch 18, item 1
# Predicted token for batch 18, item 2: [MASK]
# Fallback used for batch 18, item 2
# Predicted token for batch 18, item 3: [MASK]
# Fallback used for batch 18, item 3
# Predicted token for batch 18, item 4: [MASK]
# Fallback used for batch 18, item 4
# Predicted token for batch 18, item 5: [MASK]
# Fallback used for batch 18, item 5
# Predicted token for batch 18, item 6: [MASK]
# Fallback used for batch 18, item 6
# Predicted token for batch 18, item 7: [MASK]
# Fallback used for batch 18, item 7
# Predicted token for batch 18, item 8: [MASK]
# Fallback used for batch 18, item 8
# Predicted token for batch 18, item 9: [MASK]
# Fallback used for batch 18, item 9
# Predicted token for batch 18, item 10: [MASK]
# Fallback used for batch 18, item 10
# Predicted token for batch 18, item 11: [MASK]
# Fallback used for batch 18, item 11
# Predicted token for batch 18, item 12: [MASK]
# Fallback used for batch 18, item 12
# Predicted token for batch 18, item 13: [MASK]
# Fallback used for batch 18, item 13
# Predicted token for batch 18, item 14: [MASK]
# Fallback used for batch 18, item 14
# Predicted token for batch 18, item 15: [MASK]
# Fallback used for batch 18, item 15
# Predicted token for batch 18, item 16: [MASK]
# Fallback used for batch 18, item 16
# Batch 18 of 119 processed.
# Predicted token for batch 19, item 1: [MASK]
# Fallback used for batch 19, item 1
# Predicted token for batch 19, item 2: [MASK]
# Fallback used for batch 19, item 2
# Predicted token for batch 19, item 3: [MASK]
# Fallback used for batch 19, item 3
# Predicted token for batch 19, item 4: [MASK]
# Fallback used for batch 19, item 4
# Predicted token for batch 19, item 5: [MASK]
# Fallback used for batch 19, item 5
# Predicted token for batch 19, item 6: [MASK]
# Fallback used for batch 19, item 6
# Predicted token for batch 19, item 7: [MASK]
# Fallback used for batch 19, item 7
# Predicted token for batch 19, item 8: [MASK]
# Fallback used for batch 19, item 8
# Predicted token for batch 19, item 9: [MASK]
# Fallback used for batch 19, item 9
# Predicted token for batch 19, item 10: [MASK]
# Fallback used for batch 19, item 10
# Predicted token for batch 19, item 11: [MASK]
# Fallback used for batch 19, item 11
# Predicted token for batch 19, item 12: [MASK]
# Fallback used for batch 19, item 12
# Predicted token for batch 19, item 13: [MASK]
# Fallback used for batch 19, item 13
# Predicted token for batch 19, item 14: [MASK]
# Fallback used for batch 19, item 14
# Predicted token for batch 19, item 15: [MASK]
# Fallback used for batch 19, item 15
# Predicted token for batch 19, item 16: [MASK]
# Fallback used for batch 19, item 16
# Batch 19 of 119 processed.
# Predicted token for batch 20, item 1: [MASK]
# Fallback used for batch 20, item 1
# Predicted token for batch 20, item 2: [MASK]
# Fallback used for batch 20, item 2
# Predicted token for batch 20, item 3: [MASK]
# Fallback used for batch 20, item 3
# Predicted token for batch 20, item 4: [MASK]
# Fallback used for batch 20, item 4
# Predicted token for batch 20, item 5: [MASK]
# Fallback used for batch 20, item 5
# Predicted token for batch 20, item 6: [MASK]
# Fallback used for batch 20, item 6
# Predicted token for batch 20, item 7: [MASK]
# Fallback used for batch 20, item 7
# Predicted token for batch 20, item 8: [MASK]
# Fallback used for batch 20, item 8
# Predicted token for batch 20, item 9: [MASK]
# Fallback used for batch 20, item 9
# Predicted token for batch 20, item 10: [MASK]
# Fallback used for batch 20, item 10
# Predicted token for batch 20, item 11: [MASK]
# Fallback used for batch 20, item 11
# Predicted token for batch 20, item 12: [MASK]
# Fallback used for batch 20, item 12
# Predicted token for batch 20, item 13: [MASK]
# Fallback used for batch 20, item 13
# Predicted token for batch 20, item 14: [MASK]
# Fallback used for batch 20, item 14
# Predicted token for batch 20, item 15: [MASK]
# Fallback used for batch 20, item 15
# Predicted token for batch 20, item 16: [MASK]
# Fallback used for batch 20, item 16
# Batch 20 of 119 processed.
# Predicted token for batch 21, item 1: [MASK]
# Fallback used for batch 21, item 1
# Predicted token for batch 21, item 2: [MASK]
# Fallback used for batch 21, item 2
# Predicted token for batch 21, item 3: [MASK]
# Fallback used for batch 21, item 3
# Predicted token for batch 21, item 4: [MASK]
# Fallback used for batch 21, item 4
# Predicted token for batch 21, item 5: [MASK]
# Fallback used for batch 21, item 5
# Predicted token for batch 21, item 6: [MASK]
# Fallback used for batch 21, item 6
# Predicted token for batch 21, item 7: [MASK]
# Fallback used for batch 21, item 7
# Predicted token for batch 21, item 8: [MASK]
# Fallback used for batch 21, item 8
# Predicted token for batch 21, item 9: [MASK]
# Fallback used for batch 21, item 9
# Predicted token for batch 21, item 10: [MASK]
# Fallback used for batch 21, item 10
# Predicted token for batch 21, item 11: [MASK]
# Fallback used for batch 21, item 11
# Predicted token for batch 21, item 12: [MASK]
# Fallback used for batch 21, item 12
# Predicted token for batch 21, item 13: [MASK]
# Fallback used for batch 21, item 13
# Predicted token for batch 21, item 14: [MASK]
# Fallback used for batch 21, item 14
# Predicted token for batch 21, item 15: [MASK]
# Fallback used for batch 21, item 15
# Predicted token for batch 21, item 16: [MASK]
# Fallback used for batch 21, item 16
# Batch 21 of 119 processed.
# Predicted token for batch 22, item 1: [MASK]
# Fallback used for batch 22, item 1
# Predicted token for batch 22, item 2: [MASK]
# Fallback used for batch 22, item 2
# Predicted token for batch 22, item 3: [MASK]
# Fallback used for batch 22, item 3
# Predicted token for batch 22, item 4: [MASK]
# Fallback used for batch 22, item 4
# Predicted token for batch 22, item 5: [MASK]
# Fallback used for batch 22, item 5
# Predicted token for batch 22, item 6: [MASK]
# Fallback used for batch 22, item 6
# Predicted token for batch 22, item 7: [MASK]
# Fallback used for batch 22, item 7
# Predicted token for batch 22, item 8: [MASK]
# Fallback used for batch 22, item 8
# Predicted token for batch 22, item 9: [MASK]
# Fallback used for batch 22, item 9
# Predicted token for batch 22, item 10: [MASK]
# Fallback used for batch 22, item 10
# Predicted token for batch 22, item 11: [MASK]
# Fallback used for batch 22, item 11
# Predicted token for batch 22, item 12: [MASK]
# Fallback used for batch 22, item 12
# Predicted token for batch 22, item 13: [MASK]
# Fallback used for batch 22, item 13
# Predicted token for batch 22, item 14: [MASK]
# Fallback used for batch 22, item 14
# Predicted token for batch 22, item 15: [MASK]
# Fallback used for batch 22, item 15
# Predicted token for batch 22, item 16: [MASK]
# Fallback used for batch 22, item 16
# Batch 22 of 119 processed.
# Predicted token for batch 23, item 1: [MASK]
# Fallback used for batch 23, item 1
# Predicted token for batch 23, item 2: [MASK]
# Fallback used for batch 23, item 2
# Predicted token for batch 23, item 3: [MASK]
# Fallback used for batch 23, item 3
# Predicted token for batch 23, item 4: [MASK]
# Fallback used for batch 23, item 4
# Predicted token for batch 23, item 5: [MASK]
# Fallback used for batch 23, item 5
# Predicted token for batch 23, item 6: [MASK]
# Fallback used for batch 23, item 6
# Predicted token for batch 23, item 7: [MASK]
# Fallback used for batch 23, item 7
# Predicted token for batch 23, item 8: [MASK]
# Fallback used for batch 23, item 8
# Predicted token for batch 23, item 9: [MASK]
# Fallback used for batch 23, item 9
# Predicted token for batch 23, item 10: [MASK]
# Fallback used for batch 23, item 10
# Predicted token for batch 23, item 11: [MASK]
# Fallback used for batch 23, item 11
# Predicted token for batch 23, item 12: [MASK]
# Fallback used for batch 23, item 12
# Predicted token for batch 23, item 13: [MASK]
# Fallback used for batch 23, item 13
# Predicted token for batch 23, item 14: [MASK]
# Fallback used for batch 23, item 14
# Predicted token for batch 23, item 15: [MASK]
# Fallback used for batch 23, item 15
# Predicted token for batch 23, item 16: [MASK]
# Fallback used for batch 23, item 16
# Batch 23 of 119 processed.
# Predicted token for batch 24, item 1: [MASK]
# Fallback used for batch 24, item 1
# Predicted token for batch 24, item 2: [MASK]
# Fallback used for batch 24, item 2
# Predicted token for batch 24, item 3: [MASK]
# Fallback used for batch 24, item 3
# Predicted token for batch 24, item 4: [MASK]
# Fallback used for batch 24, item 4
# Predicted token for batch 24, item 5: [MASK]
# Fallback used for batch 24, item 5
# Predicted token for batch 24, item 6: [MASK]
# Fallback used for batch 24, item 6
# Predicted token for batch 24, item 7: [MASK]
# Fallback used for batch 24, item 7
# Predicted token for batch 24, item 8: [MASK]
# Fallback used for batch 24, item 8
# Predicted token for batch 24, item 9: [MASK]
# Fallback used for batch 24, item 9
# Predicted token for batch 24, item 10: [MASK]
# Fallback used for batch 24, item 10
# Predicted token for batch 24, item 11: [MASK]
# Fallback used for batch 24, item 11
# Predicted token for batch 24, item 12: [MASK]
# Fallback used for batch 24, item 12
# Predicted token for batch 24, item 13: [MASK]
# Fallback used for batch 24, item 13
# Predicted token for batch 24, item 14: [MASK]
# Fallback used for batch 24, item 14
# Predicted token for batch 24, item 15: [MASK]
# Fallback used for batch 24, item 15
# Predicted token for batch 24, item 16: [MASK]
# Fallback used for batch 24, item 16
# Batch 24 of 119 processed.
# Predicted token for batch 25, item 1: [MASK]
# Fallback used for batch 25, item 1
# Predicted token for batch 25, item 2: [MASK]
# Fallback used for batch 25, item 2
# Predicted token for batch 25, item 3: [MASK]
# Fallback used for batch 25, item 3
# Predicted token for batch 25, item 4: [MASK]
# Fallback used for batch 25, item 4
# Predicted token for batch 25, item 5: [MASK]
# Fallback used for batch 25, item 5
# Predicted token for batch 25, item 6: [MASK]
# Fallback used for batch 25, item 6
# Predicted token for batch 25, item 7: [MASK]
# Fallback used for batch 25, item 7
# Predicted token for batch 25, item 8: [MASK]
# Fallback used for batch 25, item 8
# Predicted token for batch 25, item 9: [MASK]
# Fallback used for batch 25, item 9
# Predicted token for batch 25, item 10: [MASK]
# Fallback used for batch 25, item 10
# Predicted token for batch 25, item 11: [MASK]
# Fallback used for batch 25, item 11
# Predicted token for batch 25, item 12: [MASK]
# Fallback used for batch 25, item 12
# Predicted token for batch 25, item 13: [MASK]
# Fallback used for batch 25, item 13
# Predicted token for batch 25, item 14: [MASK]
# Fallback used for batch 25, item 14
# Predicted token for batch 25, item 15: [MASK]
# Fallback used for batch 25, item 15
# Predicted token for batch 25, item 16: [MASK]
# Fallback used for batch 25, item 16
# Batch 25 of 119 processed.
# Predicted token for batch 26, item 1: [MASK]
# Fallback used for batch 26, item 1
# Predicted token for batch 26, item 2: [MASK]
# Fallback used for batch 26, item 2
# Predicted token for batch 26, item 3: [MASK]
# Fallback used for batch 26, item 3
# Predicted token for batch 26, item 4: [MASK]
# Fallback used for batch 26, item 4
# Predicted token for batch 26, item 5: [MASK]
# Fallback used for batch 26, item 5
# Predicted token for batch 26, item 6: [MASK]
# Fallback used for batch 26, item 6
# Predicted token for batch 26, item 7: [MASK]
# Fallback used for batch 26, item 7
# Predicted token for batch 26, item 8: [MASK]
# Fallback used for batch 26, item 8
# Predicted token for batch 26, item 9: [MASK]
# Fallback used for batch 26, item 9
# Predicted token for batch 26, item 10: [MASK]
# Fallback used for batch 26, item 10
# Predicted token for batch 26, item 11: [MASK]
# Fallback used for batch 26, item 11
# Predicted token for batch 26, item 12: [MASK]
# Fallback used for batch 26, item 12
# Predicted token for batch 26, item 13: [MASK]
# Fallback used for batch 26, item 13
# Predicted token for batch 26, item 14: [MASK]
# Fallback used for batch 26, item 14
# Predicted token for batch 26, item 15: [MASK]
# Fallback used for batch 26, item 15
# Predicted token for batch 26, item 16: [MASK]
# Fallback used for batch 26, item 16
# Batch 26 of 119 processed.
# Predicted token for batch 27, item 1: [MASK]
# Fallback used for batch 27, item 1
# Predicted token for batch 27, item 2: [MASK]
# Fallback used for batch 27, item 2
# Predicted token for batch 27, item 3: [MASK]
# Fallback used for batch 27, item 3
# Predicted token for batch 27, item 4: [MASK]
# Fallback used for batch 27, item 4
# Predicted token for batch 27, item 5: [MASK]
# Fallback used for batch 27, item 5
# Predicted token for batch 27, item 6: [MASK]
# Fallback used for batch 27, item 6
# Predicted token for batch 27, item 7: [MASK]
# Fallback used for batch 27, item 7
# Predicted token for batch 27, item 8: [MASK]
# Fallback used for batch 27, item 8
# Predicted token for batch 27, item 9: [MASK]
# Fallback used for batch 27, item 9
# Predicted token for batch 27, item 10: [MASK]
# Fallback used for batch 27, item 10
# Predicted token for batch 27, item 11: [MASK]
# Fallback used for batch 27, item 11
# Predicted token for batch 27, item 12: [MASK]
# Fallback used for batch 27, item 12
# Predicted token for batch 27, item 13: [MASK]
# Fallback used for batch 27, item 13
# Predicted token for batch 27, item 14: [MASK]
# Fallback used for batch 27, item 14
# Predicted token for batch 27, item 15: [MASK]
# Fallback used for batch 27, item 15
# Predicted token for batch 27, item 16: [MASK]
# Fallback used for batch 27, item 16
# Batch 27 of 119 processed.
# Predicted token for batch 28, item 1: [MASK]
# Fallback used for batch 28, item 1
# Predicted token for batch 28, item 2: [MASK]
# Fallback used for batch 28, item 2
# Predicted token for batch 28, item 3: [MASK]
# Fallback used for batch 28, item 3
# Predicted token for batch 28, item 4: [MASK]
# Fallback used for batch 28, item 4
# Predicted token for batch 28, item 5: [MASK]
# Fallback used for batch 28, item 5
# Predicted token for batch 28, item 6: [MASK]
# Fallback used for batch 28, item 6
# Predicted token for batch 28, item 7: [MASK]
# Fallback used for batch 28, item 7
# Predicted token for batch 28, item 8: [MASK]
# Fallback used for batch 28, item 8
# Predicted token for batch 28, item 9: [MASK]
# Fallback used for batch 28, item 9
# Predicted token for batch 28, item 10: [MASK]
# Fallback used for batch 28, item 10
# Predicted token for batch 28, item 11: [MASK]
# Fallback used for batch 28, item 11
# Predicted token for batch 28, item 12: [MASK]
# Fallback used for batch 28, item 12
# Predicted token for batch 28, item 13: [MASK]
# Fallback used for batch 28, item 13
# Predicted token for batch 28, item 14: [MASK]
# Fallback used for batch 28, item 14
# Predicted token for batch 28, item 15: [MASK]
# Fallback used for batch 28, item 15
# Predicted token for batch 28, item 16: [MASK]
# Fallback used for batch 28, item 16
# Batch 28 of 119 processed.
# Predicted token for batch 29, item 1: [MASK]
# Fallback used for batch 29, item 1
# Predicted token for batch 29, item 2: [MASK]
# Fallback used for batch 29, item 2
# Predicted token for batch 29, item 3: [MASK]
# Fallback used for batch 29, item 3
# Predicted token for batch 29, item 4: [MASK]
# Fallback used for batch 29, item 4
# Predicted token for batch 29, item 5: [MASK]
# Fallback used for batch 29, item 5
# Predicted token for batch 29, item 6: [MASK]
# Fallback used for batch 29, item 6
# Predicted token for batch 29, item 7: [MASK]
# Fallback used for batch 29, item 7
# Predicted token for batch 29, item 8: [MASK]
# Fallback used for batch 29, item 8
# Predicted token for batch 29, item 9: [MASK]
# Fallback used for batch 29, item 9
# Predicted token for batch 29, item 10: [MASK]
# Fallback used for batch 29, item 10
# Predicted token for batch 29, item 11: [MASK]
# Fallback used for batch 29, item 11
# Predicted token for batch 29, item 12: [MASK]
# Fallback used for batch 29, item 12
# Predicted token for batch 29, item 13: [MASK]
# Fallback used for batch 29, item 13
# Predicted token for batch 29, item 14: [MASK]
# Fallback used for batch 29, item 14
# Predicted token for batch 29, item 15: [MASK]
# Fallback used for batch 29, item 15
# Predicted token for batch 29, item 16: [MASK]
# Fallback used for batch 29, item 16
# Batch 29 of 119 processed.
# Predicted token for batch 30, item 1: [MASK]
# Fallback used for batch 30, item 1
# Predicted token for batch 30, item 2: [MASK]
# Fallback used for batch 30, item 2
# Predicted token for batch 30, item 3: [MASK]
# Fallback used for batch 30, item 3
# Predicted token for batch 30, item 4: [MASK]
# Fallback used for batch 30, item 4
# Predicted token for batch 30, item 5: [MASK]
# Fallback used for batch 30, item 5
# Predicted token for batch 30, item 6: [MASK]
# Fallback used for batch 30, item 6
# Predicted token for batch 30, item 7: [MASK]
# Fallback used for batch 30, item 7
# Predicted token for batch 30, item 8: [MASK]
# Fallback used for batch 30, item 8
# Predicted token for batch 30, item 9: [MASK]
# Fallback used for batch 30, item 9
# Predicted token for batch 30, item 10: [MASK]
# Fallback used for batch 30, item 10
# Predicted token for batch 30, item 11: [MASK]
# Fallback used for batch 30, item 11
# Predicted token for batch 30, item 12: [MASK]
# Fallback used for batch 30, item 12
# Predicted token for batch 30, item 13: [MASK]
# Fallback used for batch 30, item 13
# Predicted token for batch 30, item 14: [MASK]
# Fallback used for batch 30, item 14
# Predicted token for batch 30, item 15: [MASK]
# Fallback used for batch 30, item 15
# Predicted token for batch 30, item 16: [MASK]
# Fallback used for batch 30, item 16
# Batch 30 of 119 processed.
# Predicted token for batch 31, item 1: [MASK]
# Fallback used for batch 31, item 1
# Predicted token for batch 31, item 2: [MASK]
# Fallback used for batch 31, item 2
# Predicted token for batch 31, item 3: [MASK]
# Fallback used for batch 31, item 3
# Predicted token for batch 31, item 4: [MASK]
# Fallback used for batch 31, item 4
# Predicted token for batch 31, item 5: [MASK]
# Fallback used for batch 31, item 5
# Predicted token for batch 31, item 6: [MASK]
# Fallback used for batch 31, item 6
# Predicted token for batch 31, item 7: [MASK]
# Fallback used for batch 31, item 7
# Predicted token for batch 31, item 8: [MASK]
# Fallback used for batch 31, item 8
# Predicted token for batch 31, item 9: [MASK]
# Fallback used for batch 31, item 9
# Predicted token for batch 31, item 10: [MASK]
# Fallback used for batch 31, item 10
# Predicted token for batch 31, item 11: [MASK]
# Fallback used for batch 31, item 11
# Predicted token for batch 31, item 12: [MASK]
# Fallback used for batch 31, item 12
# Predicted token for batch 31, item 13: [MASK]
# Fallback used for batch 31, item 13
# Predicted token for batch 31, item 14: [MASK]
# Fallback used for batch 31, item 14
# Predicted token for batch 31, item 15: [MASK]
# Fallback used for batch 31, item 15
# Predicted token for batch 31, item 16: [MASK]
# Fallback used for batch 31, item 16
# Batch 31 of 119 processed.
# Predicted token for batch 32, item 1: [MASK]
# Fallback used for batch 32, item 1
# Predicted token for batch 32, item 2: [MASK]
# Fallback used for batch 32, item 2
# Predicted token for batch 32, item 3: [MASK]
# Fallback used for batch 32, item 3
# Predicted token for batch 32, item 4: [MASK]
# Fallback used for batch 32, item 4
# Predicted token for batch 32, item 5: [MASK]
# Fallback used for batch 32, item 5
# Predicted token for batch 32, item 6: [MASK]
# Fallback used for batch 32, item 6
# Predicted token for batch 32, item 7: [MASK]
# Fallback used for batch 32, item 7
# Predicted token for batch 32, item 8: [MASK]
# Fallback used for batch 32, item 8
# Predicted token for batch 32, item 9: [MASK]
# Fallback used for batch 32, item 9
# Predicted token for batch 32, item 10: [MASK]
# Fallback used for batch 32, item 10
# Predicted token for batch 32, item 11: [MASK]
# Fallback used for batch 32, item 11
# Predicted token for batch 32, item 12: [MASK]
# Fallback used for batch 32, item 12
# Predicted token for batch 32, item 13: [MASK]
# Fallback used for batch 32, item 13
# Predicted token for batch 32, item 14: [MASK]
# Fallback used for batch 32, item 14
# Predicted token for batch 32, item 15: [MASK]
# Fallback used for batch 32, item 15
# Predicted token for batch 32, item 16: [MASK]
# Fallback used for batch 32, item 16
# Batch 32 of 119 processed.
# Predicted token for batch 33, item 1: [MASK]
# Fallback used for batch 33, item 1
# Predicted token for batch 33, item 2: [MASK]
# Fallback used for batch 33, item 2
# Predicted token for batch 33, item 3: [MASK]
# Fallback used for batch 33, item 3
# Predicted token for batch 33, item 4: [MASK]
# Fallback used for batch 33, item 4
# Predicted token for batch 33, item 5: [MASK]
# Fallback used for batch 33, item 5
# Predicted token for batch 33, item 6: [MASK]
# Fallback used for batch 33, item 6
# Predicted token for batch 33, item 7: [MASK]
# Fallback used for batch 33, item 7
# Predicted token for batch 33, item 8: [MASK]
# Fallback used for batch 33, item 8
# Predicted token for batch 33, item 9: [MASK]
# Fallback used for batch 33, item 9
# Predicted token for batch 33, item 10: [MASK]
# Fallback used for batch 33, item 10
# Predicted token for batch 33, item 11: [MASK]
# Fallback used for batch 33, item 11
# Predicted token for batch 33, item 12: [MASK]
# Fallback used for batch 33, item 12
# Predicted token for batch 33, item 13: [MASK]
# Fallback used for batch 33, item 13
# Predicted token for batch 33, item 14: [MASK]
# Fallback used for batch 33, item 14
# Predicted token for batch 33, item 15: [MASK]
# Fallback used for batch 33, item 15
# Predicted token for batch 33, item 16: [MASK]
# Fallback used for batch 33, item 16
# Batch 33 of 119 processed.
# Predicted token for batch 34, item 1: [MASK]
# Fallback used for batch 34, item 1
# Predicted token for batch 34, item 2: [MASK]
# Fallback used for batch 34, item 2
# Predicted token for batch 34, item 3: [MASK]
# Fallback used for batch 34, item 3
# Predicted token for batch 34, item 4: [MASK]
# Fallback used for batch 34, item 4
# Predicted token for batch 34, item 5: [MASK]
# Fallback used for batch 34, item 5
# Predicted token for batch 34, item 6: [MASK]
# Fallback used for batch 34, item 6
# Predicted token for batch 34, item 7: [MASK]
# Fallback used for batch 34, item 7
# Predicted token for batch 34, item 8: [MASK]
# Fallback used for batch 34, item 8
# Predicted token for batch 34, item 9: [MASK]
# Fallback used for batch 34, item 9
# Predicted token for batch 34, item 10: [MASK]
# ...
# Fallback used for batch 107, item 11
# Predicted token for batch 107, item 12: [MASK]
# Fallback used for batch 107, item 12
# Predicted token for batch 107, item 13: [MASK]
# Fallback used for batch 107, item 13
# Predicted token for batch 107, item 14: [MASK]
# Fallback used for batch 107, item 14
# Predicted token for batch 107, item 15: [MASK]
# Fallback used for batch 107, item 15
# Predicted token for batch 107, item 16: [MASK]
# Fallback used for batch 107, item 16
# Batch 107 of 119 processed.
# Predicted token for batch 108, item 1: [MASK]
# Fallback used for batch 108, item 1
# Predicted token for batch 108, item 2: [MASK]
# Fallback used for batch 108, item 2
# Predicted token for batch 108, item 3: [MASK]
# Fallback used for batch 108, item 3
# Predicted token for batch 108, item 4: [MASK]
# Fallback used for batch 108, item 4
# Predicted token for batch 108, item 5: [MASK]
# Fallback used for batch 108, item 5
# Predicted token for batch 108, item 6: [MASK]
# Fallback used for batch 108, item 6
# Predicted token for batch 108, item 7: [MASK]
# Fallback used for batch 108, item 7
# Predicted token for batch 108, item 8: [MASK]
# Fallback used for batch 108, item 8
# Predicted token for batch 108, item 9: [MASK]
# Fallback used for batch 108, item 9
# Predicted token for batch 108, item 10: [MASK]
# Fallback used for batch 108, item 10
# Predicted token for batch 108, item 11: [MASK]
# Fallback used for batch 108, item 11
# Predicted token for batch 108, item 12: [MASK]
# Fallback used for batch 108, item 12
# Predicted token for batch 108, item 13: [MASK]
# Fallback used for batch 108, item 13
# Predicted token for batch 108, item 14: [MASK]
# Fallback used for batch 108, item 14
# Predicted token for batch 108, item 15: [MASK]
# Fallback used for batch 108, item 15
# Predicted token for batch 108, item 16: [MASK]
# Fallback used for batch 108, item 16
# Batch 108 of 119 processed.
# Predicted token for batch 109, item 1: [MASK]
# Fallback used for batch 109, item 1
# Predicted token for batch 109, item 2: [MASK]
# Fallback used for batch 109, item 2
# Predicted token for batch 109, item 3: [MASK]
# Fallback used for batch 109, item 3
# Predicted token for batch 109, item 4: [MASK]
# Fallback used for batch 109, item 4
# Predicted token for batch 109, item 5: [MASK]
# Fallback used for batch 109, item 5
# Predicted token for batch 109, item 6: [MASK]
# Fallback used for batch 109, item 6
# Predicted token for batch 109, item 7: [MASK]
# Fallback used for batch 109, item 7
# Predicted token for batch 109, item 8: [MASK]
# Fallback used for batch 109, item 8
# Predicted token for batch 109, item 9: [MASK]
# Fallback used for batch 109, item 9
# Predicted token for batch 109, item 10: [MASK]
# Fallback used for batch 109, item 10
# Predicted token for batch 109, item 11: [MASK]
# Fallback used for batch 109, item 11
# Predicted token for batch 109, item 12: [MASK]
# Fallback used for batch 109, item 12
# Predicted token for batch 109, item 13: [MASK]
# Fallback used for batch 109, item 13
# Predicted token for batch 109, item 14: [MASK]
# Fallback used for batch 109, item 14
# Predicted token for batch 109, item 15: [MASK]
# Fallback used for batch 109, item 15
# Predicted token for batch 109, item 16: [MASK]
# Fallback used for batch 109, item 16
# Batch 109 of 119 processed.
# Predicted token for batch 110, item 1: [MASK]
# Fallback used for batch 110, item 1
# Predicted token for batch 110, item 2: [MASK]
# Fallback used for batch 110, item 2
# Predicted token for batch 110, item 3: [MASK]
# Fallback used for batch 110, item 3
# Predicted token for batch 110, item 4: [MASK]
# Fallback used for batch 110, item 4
# Predicted token for batch 110, item 5: [MASK]
# Fallback used for batch 110, item 5
# Predicted token for batch 110, item 6: [MASK]
# Fallback used for batch 110, item 6
# Predicted token for batch 110, item 7: [MASK]
# Fallback used for batch 110, item 7
# Predicted token for batch 110, item 8: [MASK]
# Fallback used for batch 110, item 8
# Predicted token for batch 110, item 9: [MASK]
# Fallback used for batch 110, item 9
# Predicted token for batch 110, item 10: [MASK]
# Fallback used for batch 110, item 10
# Predicted token for batch 110, item 11: [MASK]
# Fallback used for batch 110, item 11
# Predicted token for batch 110, item 12: [MASK]
# Fallback used for batch 110, item 12
# Predicted token for batch 110, item 13: [MASK]
# Fallback used for batch 110, item 13
# Predicted token for batch 110, item 14: [MASK]
# Fallback used for batch 110, item 14
# Predicted token for batch 110, item 15: [MASK]
# Fallback used for batch 110, item 15
# Predicted token for batch 110, item 16: [MASK]
# Fallback used for batch 110, item 16
# Batch 110 of 119 processed.
# Predicted token for batch 111, item 1: [MASK]
# Fallback used for batch 111, item 1
# Predicted token for batch 111, item 2: [MASK]
# Fallback used for batch 111, item 2
# Predicted token for batch 111, item 3: [MASK]
# Fallback used for batch 111, item 3
# Predicted token for batch 111, item 4: [MASK]
# Fallback used for batch 111, item 4
# Predicted token for batch 111, item 5: [MASK]
# Fallback used for batch 111, item 5
# Predicted token for batch 111, item 6: [MASK]
# Fallback used for batch 111, item 6
# Predicted token for batch 111, item 7: [MASK]
# Fallback used for batch 111, item 7
# Predicted token for batch 111, item 8: [MASK]
# Fallback used for batch 111, item 8
# Predicted token for batch 111, item 9: [MASK]
# Fallback used for batch 111, item 9
# Predicted token for batch 111, item 10: [MASK]
# Fallback used for batch 111, item 10
# Predicted token for batch 111, item 11: [MASK]
# Fallback used for batch 111, item 11
# Predicted token for batch 111, item 12: [MASK]
# Fallback used for batch 111, item 12
# Predicted token for batch 111, item 13: [MASK]
# Fallback used for batch 111, item 13
# Predicted token for batch 111, item 14: [MASK]
# Fallback used for batch 111, item 14
# Predicted token for batch 111, item 15: [MASK]
# Fallback used for batch 111, item 15
# Predicted token for batch 111, item 16: [MASK]
# Fallback used for batch 111, item 16
# Batch 111 of 119 processed.
# Predicted token for batch 112, item 1: [MASK]
# Fallback used for batch 112, item 1
# Predicted token for batch 112, item 2: [MASK]
# Fallback used for batch 112, item 2
# Predicted token for batch 112, item 3: [MASK]
# Fallback used for batch 112, item 3
# Predicted token for batch 112, item 4: [MASK]
# Fallback used for batch 112, item 4
# Predicted token for batch 112, item 5: [MASK]
# Fallback used for batch 112, item 5
# Predicted token for batch 112, item 6: [MASK]
# Fallback used for batch 112, item 6
# Predicted token for batch 112, item 7: [MASK]
# Fallback used for batch 112, item 7
# Predicted token for batch 112, item 8: [MASK]
# Fallback used for batch 112, item 8
# Predicted token for batch 112, item 9: [MASK]
# Fallback used for batch 112, item 9
# Predicted token for batch 112, item 10: [MASK]
# Fallback used for batch 112, item 10
# Predicted token for batch 112, item 11: [MASK]
# Fallback used for batch 112, item 11
# Predicted token for batch 112, item 12: [MASK]
# Fallback used for batch 112, item 12
# Predicted token for batch 112, item 13: [MASK]
# Fallback used for batch 112, item 13
# Predicted token for batch 112, item 14: [MASK]
# Fallback used for batch 112, item 14
# Predicted token for batch 112, item 15: [MASK]
# Fallback used for batch 112, item 15
# Predicted token for batch 112, item 16: [MASK]
# Fallback used for batch 112, item 16
# Batch 112 of 119 processed.
# Predicted token for batch 113, item 1: [MASK]
# Fallback used for batch 113, item 1
# Predicted token for batch 113, item 2: [MASK]
# Fallback used for batch 113, item 2
# Predicted token for batch 113, item 3: [MASK]
# Fallback used for batch 113, item 3
# Predicted token for batch 113, item 4: [MASK]
# Fallback used for batch 113, item 4
# Predicted token for batch 113, item 5: [MASK]
# Fallback used for batch 113, item 5
# Predicted token for batch 113, item 6: [MASK]
# Fallback used for batch 113, item 6
# Predicted token for batch 113, item 7: [MASK]
# Fallback used for batch 113, item 7
# Predicted token for batch 113, item 8: [MASK]
# Fallback used for batch 113, item 8
# Predicted token for batch 113, item 9: [MASK]
# Fallback used for batch 113, item 9
# Predicted token for batch 113, item 10: [MASK]
# Fallback used for batch 113, item 10
# Predicted token for batch 113, item 11: [MASK]
# Fallback used for batch 113, item 11
# Predicted token for batch 113, item 12: [MASK]
# Fallback used for batch 113, item 12
# Predicted token for batch 113, item 13: [MASK]
# Fallback used for batch 113, item 13
# Predicted token for batch 113, item 14: [MASK]
# Fallback used for batch 113, item 14
# Predicted token for batch 113, item 15: [MASK]
# Fallback used for batch 113, item 15
# Predicted token for batch 113, item 16: [MASK]
# Fallback used for batch 113, item 16
# Batch 113 of 119 processed.
# Predicted token for batch 114, item 1: [MASK]
# Fallback used for batch 114, item 1
# Predicted token for batch 114, item 2: [MASK]
# Fallback used for batch 114, item 2
# Predicted token for batch 114, item 3: [MASK]
# Fallback used for batch 114, item 3
# Predicted token for batch 114, item 4: [MASK]
# Fallback used for batch 114, item 4
# Predicted token for batch 114, item 5: [MASK]
# Fallback used for batch 114, item 5
# Predicted token for batch 114, item 6: [MASK]
# Fallback used for batch 114, item 6
# Predicted token for batch 114, item 7: [MASK]
# Fallback used for batch 114, item 7
# Predicted token for batch 114, item 8: [MASK]
# Fallback used for batch 114, item 8
# Predicted token for batch 114, item 9: [MASK]
# Fallback used for batch 114, item 9
# Predicted token for batch 114, item 10: [MASK]
# Fallback used for batch 114, item 10
# Predicted token for batch 114, item 11: [MASK]
# Fallback used for batch 114, item 11
# Predicted token for batch 114, item 12: [MASK]
# Fallback used for batch 114, item 12
# Predicted token for batch 114, item 13: [MASK]
# Fallback used for batch 114, item 13
# Predicted token for batch 114, item 14: [MASK]
# Fallback used for batch 114, item 14
# Predicted token for batch 114, item 15: [MASK]
# Fallback used for batch 114, item 15
# Predicted token for batch 114, item 16: [MASK]
# Fallback used for batch 114, item 16
# Batch 114 of 119 processed.
# Predicted token for batch 115, item 1: [MASK]
# Fallback used for batch 115, item 1
# Predicted token for batch 115, item 2: [MASK]
# Fallback used for batch 115, item 2
# Predicted token for batch 115, item 3: [MASK]
# Fallback used for batch 115, item 3
# Predicted token for batch 115, item 4: [MASK]
# Fallback used for batch 115, item 4
# Predicted token for batch 115, item 5: [MASK]
# Fallback used for batch 115, item 5
# Predicted token for batch 115, item 6: [MASK]
# Fallback used for batch 115, item 6
# Predicted token for batch 115, item 7: [MASK]
# Fallback used for batch 115, item 7
# Predicted token for batch 115, item 8: [MASK]
# Fallback used for batch 115, item 8
# Predicted token for batch 115, item 9: [MASK]
# Fallback used for batch 115, item 9
# Predicted token for batch 115, item 10: [MASK]
# Fallback used for batch 115, item 10
# Predicted token for batch 115, item 11: [MASK]
# Fallback used for batch 115, item 11
# Predicted token for batch 115, item 12: [MASK]
# Fallback used for batch 115, item 12
# Predicted token for batch 115, item 13: [MASK]
# Fallback used for batch 115, item 13
# Predicted token for batch 115, item 14: [MASK]
# Fallback used for batch 115, item 14
# Predicted token for batch 115, item 15: [MASK]
# Fallback used for batch 115, item 15
# Predicted token for batch 115, item 16: [MASK]
# Fallback used for batch 115, item 16
# Batch 115 of 119 processed.
# Predicted token for batch 116, item 1: [MASK]
# Fallback used for batch 116, item 1
# Predicted token for batch 116, item 2: [MASK]
# Fallback used for batch 116, item 2
# Predicted token for batch 116, item 3: [MASK]
# Fallback used for batch 116, item 3
# Predicted token for batch 116, item 4: [MASK]
# Fallback used for batch 116, item 4
# Predicted token for batch 116, item 5: [MASK]
# Fallback used for batch 116, item 5
# Predicted token for batch 116, item 6: [MASK]
# Fallback used for batch 116, item 6
# Predicted token for batch 116, item 7: [MASK]
# Fallback used for batch 116, item 7
# Predicted token for batch 116, item 8: [MASK]
# Fallback used for batch 116, item 8
# Predicted token for batch 116, item 9: [MASK]
# Fallback used for batch 116, item 9
# Predicted token for batch 116, item 10: [MASK]
# Fallback used for batch 116, item 10
# Predicted token for batch 116, item 11: [MASK]
# Fallback used for batch 116, item 11
# Predicted token for batch 116, item 12: [MASK]
# Fallback used for batch 116, item 12
# Predicted token for batch 116, item 13: [MASK]
# Fallback used for batch 116, item 13
# Predicted token for batch 116, item 14: [MASK]
# Fallback used for batch 116, item 14
# Predicted token for batch 116, item 15: [MASK]
# Fallback used for batch 116, item 15
# Predicted token for batch 116, item 16: [MASK]
# Fallback used for batch 116, item 16
# Batch 116 of 119 processed.
# Predicted token for batch 117, item 1: [MASK]
# Fallback used for batch 117, item 1
# Predicted token for batch 117, item 2: [MASK]
# Fallback used for batch 117, item 2
# Predicted token for batch 117, item 3: [MASK]
# Fallback used for batch 117, item 3
# Predicted token for batch 117, item 4: [MASK]
# Fallback used for batch 117, item 4
# Predicted token for batch 117, item 5: [MASK]
# Fallback used for batch 117, item 5
# Predicted token for batch 117, item 6: [MASK]
# Fallback used for batch 117, item 6
# Predicted token for batch 117, item 7: [MASK]
# Fallback used for batch 117, item 7
# Predicted token for batch 117, item 8: [MASK]
# Fallback used for batch 117, item 8
# Predicted token for batch 117, item 9: [MASK]
# Fallback used for batch 117, item 9
# Predicted token for batch 117, item 10: [MASK]
# Fallback used for batch 117, item 10
# Predicted token for batch 117, item 11: [MASK]
# Fallback used for batch 117, item 11
# Predicted token for batch 117, item 12: [MASK]
# Fallback used for batch 117, item 12
# Predicted token for batch 117, item 13: [MASK]
# Fallback used for batch 117, item 13
# Predicted token for batch 117, item 14: [MASK]
# Fallback used for batch 117, item 14
# Predicted token for batch 117, item 15: [MASK]
# Fallback used for batch 117, item 15
# Predicted token for batch 117, item 16: [MASK]
# Fallback used for batch 117, item 16
# Batch 117 of 119 processed.
# Predicted token for batch 118, item 1: [MASK]
# Fallback used for batch 118, item 1
# Predicted token for batch 118, item 2: [MASK]
# Fallback used for batch 118, item 2
# Predicted token for batch 118, item 3: [MASK]
# Fallback used for batch 118, item 3
# Predicted token for batch 118, item 4: [MASK]
# Fallback used for batch 118, item 4
# Predicted token for batch 118, item 5: [MASK]
# Fallback used for batch 118, item 5
# Predicted token for batch 118, item 6: [MASK]
# Fallback used for batch 118, item 6
# Predicted token for batch 118, item 7: [MASK]
# Fallback used for batch 118, item 7
# Predicted token for batch 118, item 8: [MASK]
# Fallback used for batch 118, item 8
# Predicted token for batch 118, item 9: [MASK]
# Fallback used for batch 118, item 9
# Predicted token for batch 118, item 10: [MASK]
# Fallback used for batch 118, item 10
# Predicted token for batch 118, item 11: [MASK]
# Fallback used for batch 118, item 11
# Predicted token for batch 118, item 12: [MASK]
# Fallback used for batch 118, item 12
# Predicted token for batch 118, item 13: [MASK]
# Fallback used for batch 118, item 13
# Predicted token for batch 118, item 14: [MASK]
# Fallback used for batch 118, item 14
# Predicted token for batch 118, item 15: [MASK]
# Fallback used for batch 118, item 15
# Predicted token for batch 118, item 16: [MASK]
# Fallback used for batch 118, item 16
# Batch 118 of 119 processed.
# Predicted token for batch 119, item 1: [MASK]
# Fallback used for batch 119, item 1
# Predicted token for batch 119, item 2: [MASK]
# Fallback used for batch 119, item 2
# Predicted token for batch 119, item 3: [MASK]
# Fallback used for batch 119, item 3
# Predicted token for batch 119, item 4: [MASK]
# Fallback used for batch 119, item 4
# Predicted token for batch 119, item 5: [MASK]
# Fallback used for batch 119, item 5
# Predicted token for batch 119, item 6: [MASK]
# Fallback used for batch 119, item 6
# Batch 119 of 119 processed.
# Mean Squared Error (MSE) of the predictions: 2560.0637885125775
# Process complete.

# %%
# !nvidia-smi
# Out:
# Wed Oct 30 20:41:37 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   77C    P0              33W /  70W |   2931MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+
